# %%
#imports 
import copy
import os
from pathlib import Path
import numpy as np 
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
'''
Gather data together 
'''


save_directory = '/Users/owainthorp/Documents/Coding/Project/Data/'
file_name = 'giro-d-italia 2000-2024.csv'
data_path = os.path.join(save_directory, file_name)

df = pd.read_csv(data_path)
X_giro = df.iloc[:, 3:7].values  # Features
y_giro = df.iloc[:, -1].values

save_directory = '/Users/owainthorp/Documents/Coding/Project/Data/'
file_name = 'tour-de-france 2000-2023.csv'
data_path = os.path.join(save_directory, file_name)

df = pd.read_csv(data_path)
X_tour = df.iloc[:, 3:7].values  # Features
y_tour = df.iloc[:, -1].values

save_directory = '/Users/owainthorp/Documents/Coding/Project/Data/'
file_name = 'vuelta-a-espana 1994-2023.csv'
data_path = os.path.join(save_directory, file_name)

df = pd.read_csv(data_path)
X_vuelta = df.iloc[:, 3:7].values  # Features
y_vuelta = df.iloc[:, -1].values

# Stack all X arrays vertically
X = np.vstack([X_giro, X_tour, X_vuelta])

# Stack all y arrays vertically
y = np.concatenate([y_giro, y_tour, y_vuelta])

# %%
#remove unprocessable data instances 
def data_clean(data, results):
    

    row_hit_list = []

    for r in range(len(data)):
        
        if 'Error' in data[r, :4]:
            row_hit_list.append(r)
            
        if results[r] == 'Error':
            row_hit_list.append(r)
    
    rows_hit_list = list(set(row_hit_list))#simple way to remove duplicates 
    
    
    if rows_hit_list:
        data = np.delete(data, rows_hit_list, axis=0)
        results = np.delete(results, rows_hit_list, axis=0) 

        
    return data, results

# %%
# Stack all X arrays vertically
X = np.vstack([X_giro, X_tour, X_vuelta])

# Stack all y arrays vertically
y = np.concatenate([y_giro, y_tour, y_vuelta])

X, y = data_clean(X,y)


X = X.astype(np.float32)
y = y.astype(np.float32)


#normalise the data 
scaler = StandardScaler()
scaler.fit(X)
X_normalised = scaler.transform(X)

np.random.seed(42)

#turn into a tensorflow object and shuffle 
indices = np.arange(len(X_normalised))
np.random.shuffle(indices)

X_normalised, y = X_normalised[indices], y[indices]

#seperate into training, validation and test
X_train, X_test, y_train, y_test = train_test_split(X_normalised, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
l1_lambda = 0.0001
reg =tf.keras.regularizers.l1(l1_lambda)


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, activation='relu', input_shape = (4,), kernel_regularizer = reg),
    tf.keras.layers.Dense(100, activation='relu',  kernel_regularizer = reg),
    tf.keras.layers.Dense(100, activation='relu',  kernel_regularizer = reg),
    tf.keras.layers.Dense(100, activation='relu',  kernel_regularizer = reg),
    tf.keras.layers.Dense(1)
])

#early stopping
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience = 10, restore_best_weights = True)

#optimizer 
optimizer = tf.keras.optimizers.AdamW(learning_rate = 1e-5)

#compile the model 
model.compile(loss='mean_squared_error',  
              metrics=['mean_absolute_error'], 
              optimizer = optimizer)



history = model.fit(X_train, y_train, epochs=500,
                   validation_data = (X_val, y_val),
                   callbacks = [early_stopping_cb])
# Out:
# Epoch 1/500
# /Users/owainthorp/anaconda3/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1553.2169 - mean_absolute_error: 16.1868 - val_loss: 1566.4324 - val_mean_absolute_error: 16.6859
# Epoch 2/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1442.5444 - mean_absolute_error: 15.7564 - val_loss: 1565.5060 - val_mean_absolute_error: 16.6842
# Epoch 3/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1674.5521 - mean_absolute_error: 17.1807 - val_loss: 1564.5723 - val_mean_absolute_error: 16.6828
# Epoch 4/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1345.0659 - mean_absolute_error: 16.2029 - val_loss: 1563.5961 - val_mean_absolute_error: 16.6810
# Epoch 5/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1563.5530 - mean_absolute_error: 16.6140 - val_loss: 1562.5984 - val_mean_absolute_error: 16.6793
# Epoch 6/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1853.3580 - mean_absolute_error: 18.3019 - val_loss: 1561.4781 - val_mean_absolute_error: 16.6773
# Epoch 7/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1681.3354 - mean_absolute_error: 17.7942 - val_loss: 1560.3234 - val_mean_absolute_error: 16.6753
# Epoch 8/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1475.4436 - mean_absolute_error: 17.9538 - val_loss: 1559.1726 - val_mean_absolute_error: 16.6732
# Epoch 9/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1765.2776 - mean_absolute_error: 17.3217 - val_loss: 1557.8207 - val_mean_absolute_error: 16.6707
# Epoch 10/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1450.7457 - mean_absolute_error: 16.1240 - val_loss: 1556.4971 - val_mean_absolute_error: 16.6684
# Epoch 11/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1785.9644 - mean_absolute_error: 17.5858 - val_loss: 1554.9758 - val_mean_absolute_error: 16.6660
# Epoch 12/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1772.5900 - mean_absolute_error: 17.8891 - val_loss: 1553.3641 - val_mean_absolute_error: 16.6631
# Epoch 13/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1512.5775 - mean_absolute_error: 17.4471 - val_loss: 1551.6476 - val_mean_absolute_error: 16.6603
# Epoch 14/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1799.1311 - mean_absolute_error: 18.1587 - val_loss: 1549.7902 - val_mean_absolute_error: 16.6572
# Epoch 15/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1363.6304 - mean_absolute_error: 16.9774 - val_loss: 1547.8235 - val_mean_absolute_error: 16.6546
# Epoch 16/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1346.8228 - mean_absolute_error: 16.4296 - val_loss: 1545.6470 - val_mean_absolute_error: 16.6524
# Epoch 17/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1166.7810 - mean_absolute_error: 14.8441 - val_loss: 1543.4197 - val_mean_absolute_error: 16.6509
# Epoch 18/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1964.7897 - mean_absolute_error: 18.6436 - val_loss: 1540.7843 - val_mean_absolute_error: 16.6485
# Epoch 19/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1393.9009 - mean_absolute_error: 17.0354 - val_loss: 1538.1512 - val_mean_absolute_error: 16.6464
# Epoch 20/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1429.3508 - mean_absolute_error: 17.1421 - val_loss: 1535.2462 - val_mean_absolute_error: 16.6442
# Epoch 21/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1787.5930 - mean_absolute_error: 17.1036 - val_loss: 1532.1896 - val_mean_absolute_error: 16.6420
# Epoch 22/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1497.9518 - mean_absolute_error: 17.3577 - val_loss: 1528.9695 - val_mean_absolute_error: 16.6400
# Epoch 23/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1187.5599 - mean_absolute_error: 16.3892 - val_loss: 1525.5306 - val_mean_absolute_error: 16.6382
# Epoch 24/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1287.4747 - mean_absolute_error: 15.8936 - val_loss: 1522.1115 - val_mean_absolute_error: 16.6367
# Epoch 25/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1540.8818 - mean_absolute_error: 17.2059 - val_loss: 1518.4009 - val_mean_absolute_error: 16.6343
# Epoch 26/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1687.0085 - mean_absolute_error: 17.4597 - val_loss: 1514.5215 - val_mean_absolute_error: 16.6324
# Epoch 27/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1493.9045 - mean_absolute_error: 16.1417 - val_loss: 1510.5360 - val_mean_absolute_error: 16.6322
# Epoch 28/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1255.6224 - mean_absolute_error: 15.4731 - val_loss: 1506.0765 - val_mean_absolute_error: 16.6333
# Epoch 29/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1590.4670 - mean_absolute_error: 17.5666 - val_loss: 1501.5148 - val_mean_absolute_error: 16.6350
# Epoch 30/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1981.4348 - mean_absolute_error: 18.6061 - val_loss: 1497.0331 - val_mean_absolute_error: 16.6377
# Epoch 31/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1482.2185 - mean_absolute_error: 16.6779 - val_loss: 1491.9248 - val_mean_absolute_error: 16.6403
# Epoch 32/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1587.7856 - mean_absolute_error: 16.1592 - val_loss: 1486.8691 - val_mean_absolute_error: 16.6434
# Epoch 33/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1688.6173 - mean_absolute_error: 18.0717 - val_loss: 1481.4366 - val_mean_absolute_error: 16.6476
# Epoch 34/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1493.5863 - mean_absolute_error: 16.0328 - val_loss: 1475.9894 - val_mean_absolute_error: 16.6524
# Epoch 35/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1643.9403 - mean_absolute_error: 18.0250 - val_loss: 1469.7432 - val_mean_absolute_error: 16.6589
# Epoch 36/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1666.7445 - mean_absolute_error: 18.7152 - val_loss: 1463.8258 - val_mean_absolute_error: 16.6644
# Epoch 37/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1500.8278 - mean_absolute_error: 17.3612 - val_loss: 1457.8596 - val_mean_absolute_error: 16.6707
# Epoch 38/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1449.2834 - mean_absolute_error: 17.5272 - val_loss: 1451.3490 - val_mean_absolute_error: 16.6781
# Epoch 39/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1458.1497 - mean_absolute_error: 17.2453 - val_loss: 1444.4468 - val_mean_absolute_error: 16.6879
# Epoch 40/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1291.2075 - mean_absolute_error: 16.1370 - val_loss: 1437.5016 - val_mean_absolute_error: 16.6973
# Epoch 41/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1244.3112 - mean_absolute_error: 16.0356 - val_loss: 1430.2719 - val_mean_absolute_error: 16.7083
# Epoch 42/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1497.4489 - mean_absolute_error: 16.9036 - val_loss: 1422.7570 - val_mean_absolute_error: 16.7208
# Epoch 43/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1664.0968 - mean_absolute_error: 17.3843 - val_loss: 1414.9315 - val_mean_absolute_error: 16.7380
# Epoch 44/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1393.1252 - mean_absolute_error: 17.3411 - val_loss: 1407.3114 - val_mean_absolute_error: 16.7530
# Epoch 45/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1380.1547 - mean_absolute_error: 16.7458 - val_loss: 1398.6198 - val_mean_absolute_error: 16.7716
# Epoch 46/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1637.0402 - mean_absolute_error: 17.9165 - val_loss: 1390.4913 - val_mean_absolute_error: 16.7911
# Epoch 47/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1268.8802 - mean_absolute_error: 15.7508 - val_loss: 1382.5085 - val_mean_absolute_error: 16.8078
# Epoch 48/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1517.1055 - mean_absolute_error: 17.8521 - val_loss: 1374.3695 - val_mean_absolute_error: 16.8281
# Epoch 49/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1338.6805 - mean_absolute_error: 17.5559 - val_loss: 1365.7274 - val_mean_absolute_error: 16.8474
# Epoch 50/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1390.9756 - mean_absolute_error: 16.4358 - val_loss: 1357.6860 - val_mean_absolute_error: 16.8662
# Epoch 51/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1697.0479 - mean_absolute_error: 18.1540 - val_loss: 1348.9891 - val_mean_absolute_error: 16.8903
# Epoch 52/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1229.3854 - mean_absolute_error: 16.5617 - val_loss: 1340.1499 - val_mean_absolute_error: 16.9149
# Epoch 53/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1409.6501 - mean_absolute_error: 16.2868 - val_loss: 1331.1973 - val_mean_absolute_error: 16.9406
# Epoch 54/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1667.1752 - mean_absolute_error: 17.7878 - val_loss: 1322.1786 - val_mean_absolute_error: 16.9705
# Epoch 55/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1456.8131 - mean_absolute_error: 17.5094 - val_loss: 1313.4042 - val_mean_absolute_error: 17.0009
# Epoch 56/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1182.1571 - mean_absolute_error: 16.2076 - val_loss: 1304.8625 - val_mean_absolute_error: 17.0277
# Epoch 57/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1707.0375 - mean_absolute_error: 18.4287 - val_loss: 1295.9159 - val_mean_absolute_error: 17.0566
# Epoch 58/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1309.6932 - mean_absolute_error: 15.9948 - val_loss: 1286.9714 - val_mean_absolute_error: 17.0850
# Epoch 59/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1507.5206 - mean_absolute_error: 17.7358 - val_loss: 1278.8215 - val_mean_absolute_error: 17.1149
# Epoch 60/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1544.5802 - mean_absolute_error: 18.3261 - val_loss: 1270.4177 - val_mean_absolute_error: 17.1502
# Epoch 61/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1539.8260 - mean_absolute_error: 18.0693 - val_loss: 1261.9443 - val_mean_absolute_error: 17.1930
# Epoch 62/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1420.3169 - mean_absolute_error: 17.9269 - val_loss: 1253.9600 - val_mean_absolute_error: 17.2365
# Epoch 63/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1208.5836 - mean_absolute_error: 17.2493 - val_loss: 1245.8932 - val_mean_absolute_error: 17.2818
# Epoch 64/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1331.8586 - mean_absolute_error: 17.4473 - val_loss: 1238.3048 - val_mean_absolute_error: 17.3265
# Epoch 65/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1412.0640 - mean_absolute_error: 16.8172 - val_loss: 1230.5181 - val_mean_absolute_error: 17.3722
# Epoch 66/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1054.5471 - mean_absolute_error: 17.1173 - val_loss: 1222.8705 - val_mean_absolute_error: 17.4211
# Epoch 67/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1174.9048 - mean_absolute_error: 16.3090 - val_loss: 1216.6237 - val_mean_absolute_error: 17.4526
# Epoch 68/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1514.0598 - mean_absolute_error: 19.6578 - val_loss: 1208.5239 - val_mean_absolute_error: 17.5180
# Epoch 69/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1458.2914 - mean_absolute_error: 18.1111 - val_loss: 1201.7673 - val_mean_absolute_error: 17.5595
# Epoch 70/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1032.2114 - mean_absolute_error: 16.7574 - val_loss: 1195.0021 - val_mean_absolute_error: 17.6156
# Epoch 71/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1094.4623 - mean_absolute_error: 17.6137 - val_loss: 1188.7351 - val_mean_absolute_error: 17.6615
# Epoch 72/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 955.1738 - mean_absolute_error: 16.7062 - val_loss: 1183.1969 - val_mean_absolute_error: 17.6998
# Epoch 73/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1104.6915 - mean_absolute_error: 17.4897 - val_loss: 1177.4390 - val_mean_absolute_error: 17.7452
# Epoch 74/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1098.2024 - mean_absolute_error: 17.3121 - val_loss: 1172.1273 - val_mean_absolute_error: 17.7839
# Epoch 75/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1126.9714 - mean_absolute_error: 17.5324 - val_loss: 1167.1283 - val_mean_absolute_error: 17.8137
# Epoch 76/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1075.9109 - mean_absolute_error: 18.2563 - val_loss: 1162.3856 - val_mean_absolute_error: 17.8494
# Epoch 77/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1059.4509 - mean_absolute_error: 17.8905 - val_loss: 1157.9794 - val_mean_absolute_error: 17.8777
# Epoch 78/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1051.1677 - mean_absolute_error: 17.1358 - val_loss: 1153.7994 - val_mean_absolute_error: 17.9033
# Epoch 79/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 995.6766 - mean_absolute_error: 17.7794 - val_loss: 1149.5565 - val_mean_absolute_error: 17.9324
# Epoch 80/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1208.6764 - mean_absolute_error: 18.2286 - val_loss: 1145.6830 - val_mean_absolute_error: 17.9504
# Epoch 81/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1267.0740 - mean_absolute_error: 18.6414 - val_loss: 1141.7513 - val_mean_absolute_error: 17.9798
# Epoch 82/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 976.0980 - mean_absolute_error: 17.5052 - val_loss: 1138.1460 - val_mean_absolute_error: 18.0048
# Epoch 83/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1285.0857 - mean_absolute_error: 18.4072 - val_loss: 1134.8750 - val_mean_absolute_error: 18.0186
# Epoch 84/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1043.1593 - mean_absolute_error: 17.8843 - val_loss: 1132.1188 - val_mean_absolute_error: 18.0343
# Epoch 85/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1016.8714 - mean_absolute_error: 17.9988 - val_loss: 1129.2321 - val_mean_absolute_error: 18.0505
# Epoch 86/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1660.9659 - mean_absolute_error: 19.8571 - val_loss: 1126.4575 - val_mean_absolute_error: 18.0653
# Epoch 87/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1271.9626 - mean_absolute_error: 19.1463 - val_loss: 1123.8789 - val_mean_absolute_error: 18.0747
# Epoch 88/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1093.2693 - mean_absolute_error: 18.5355 - val_loss: 1121.2302 - val_mean_absolute_error: 18.0939
# Epoch 89/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1365.0917 - mean_absolute_error: 18.4302 - val_loss: 1119.4618 - val_mean_absolute_error: 18.0923
# Epoch 90/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 992.8283 - mean_absolute_error: 18.2041 - val_loss: 1117.5315 - val_mean_absolute_error: 18.0983
# Epoch 91/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 872.3719 - mean_absolute_error: 17.5277 - val_loss: 1115.3865 - val_mean_absolute_error: 18.1114
# Epoch 92/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1104.4253 - mean_absolute_error: 17.6720 - val_loss: 1113.5182 - val_mean_absolute_error: 18.1178
# Epoch 93/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 914.0806 - mean_absolute_error: 17.4299 - val_loss: 1111.5873 - val_mean_absolute_error: 18.1328
# Epoch 94/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 882.1526 - mean_absolute_error: 17.3676 - val_loss: 1109.9260 - val_mean_absolute_error: 18.1400
# Epoch 95/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1062.1011 - mean_absolute_error: 18.2487 - val_loss: 1108.1918 - val_mean_absolute_error: 18.1620
# Epoch 96/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1144.5337 - mean_absolute_error: 18.4898 - val_loss: 1106.8068 - val_mean_absolute_error: 18.1630
# Epoch 97/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1261.9141 - mean_absolute_error: 19.5168 - val_loss: 1105.4170 - val_mean_absolute_error: 18.1707
# Epoch 98/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1154.5612 - mean_absolute_error: 17.4978 - val_loss: 1104.6240 - val_mean_absolute_error: 18.1574
# Epoch 99/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1192.9242 - mean_absolute_error: 18.7622 - val_loss: 1103.0945 - val_mean_absolute_error: 18.1778
# Epoch 100/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1254.9459 - mean_absolute_error: 19.0733 - val_loss: 1101.8976 - val_mean_absolute_error: 18.1765
# Epoch 101/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1205.6227 - mean_absolute_error: 18.7642 - val_loss: 1101.1975 - val_mean_absolute_error: 18.1598
# Epoch 102/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1096.5338 - mean_absolute_error: 18.5525 - val_loss: 1100.4219 - val_mean_absolute_error: 18.1539
# Epoch 103/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 945.7792 - mean_absolute_error: 17.7199 - val_loss: 1099.9976 - val_mean_absolute_error: 18.1237
# Epoch 104/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1286.0343 - mean_absolute_error: 19.1578 - val_loss: 1098.8616 - val_mean_absolute_error: 18.1370
# Epoch 105/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1520.9774 - mean_absolute_error: 20.0822 - val_loss: 1098.0555 - val_mean_absolute_error: 18.1432
# Epoch 106/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 898.2955 - mean_absolute_error: 17.9031 - val_loss: 1097.8213 - val_mean_absolute_error: 18.1117
# Epoch 107/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 947.0500 - mean_absolute_error: 17.8502 - val_loss: 1096.5931 - val_mean_absolute_error: 18.1241
# Epoch 108/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 991.7189 - mean_absolute_error: 17.4306 - val_loss: 1096.0795 - val_mean_absolute_error: 18.1122
# Epoch 109/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 822.3411 - mean_absolute_error: 17.2939 - val_loss: 1095.7010 - val_mean_absolute_error: 18.0916
# Epoch 110/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1350.5426 - mean_absolute_error: 19.6945 - val_loss: 1095.0781 - val_mean_absolute_error: 18.0928
# Epoch 111/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1221.0891 - mean_absolute_error: 19.0186 - val_loss: 1094.6526 - val_mean_absolute_error: 18.0777
# Epoch 112/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1307.1333 - mean_absolute_error: 19.3244 - val_loss: 1094.3390 - val_mean_absolute_error: 18.0562
# Epoch 113/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1169.8733 - mean_absolute_error: 18.0497 - val_loss: 1094.2579 - val_mean_absolute_error: 18.0309
# Epoch 114/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 884.7090 - mean_absolute_error: 17.7408 - val_loss: 1093.8114 - val_mean_absolute_error: 18.0199
# Epoch 115/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1238.1926 - mean_absolute_error: 18.6981 - val_loss: 1093.2462 - val_mean_absolute_error: 18.0378
# Epoch 116/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1215.0800 - mean_absolute_error: 18.8244 - val_loss: 1093.0248 - val_mean_absolute_error: 18.0207
# Epoch 117/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1309.8101 - mean_absolute_error: 19.4167 - val_loss: 1092.6005 - val_mean_absolute_error: 18.0174
# Epoch 118/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1359.5452 - mean_absolute_error: 19.7661 - val_loss: 1092.5275 - val_mean_absolute_error: 18.0004
# Epoch 119/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1259.9568 - mean_absolute_error: 18.2222 - val_loss: 1092.0885 - val_mean_absolute_error: 18.0017
# Epoch 120/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1031.5726 - mean_absolute_error: 18.3440 - val_loss: 1091.7262 - val_mean_absolute_error: 18.0101
# Epoch 121/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 859.7894 - mean_absolute_error: 16.4521 - val_loss: 1091.5809 - val_mean_absolute_error: 17.9876
# Epoch 122/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1348.3910 - mean_absolute_error: 19.2133 - val_loss: 1091.2722 - val_mean_absolute_error: 17.9985
# Epoch 123/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1328.0963 - mean_absolute_error: 20.0786 - val_loss: 1091.0812 - val_mean_absolute_error: 17.9832
# Epoch 124/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1131.4639 - mean_absolute_error: 17.9834 - val_loss: 1091.0323 - val_mean_absolute_error: 17.9654
# Epoch 125/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1293.9927 - mean_absolute_error: 19.9184 - val_loss: 1090.7686 - val_mean_absolute_error: 17.9645
# Epoch 126/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 966.2596 - mean_absolute_error: 18.0106 - val_loss: 1090.6599 - val_mean_absolute_error: 17.9441
# Epoch 127/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1291.7653 - mean_absolute_error: 19.8716 - val_loss: 1090.6091 - val_mean_absolute_error: 17.9290
# Epoch 128/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1139.0901 - mean_absolute_error: 18.6948 - val_loss: 1090.4993 - val_mean_absolute_error: 17.9160
# Epoch 129/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 874.7874 - mean_absolute_error: 17.2328 - val_loss: 1090.4049 - val_mean_absolute_error: 17.9029
# Epoch 130/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1546.0294 - mean_absolute_error: 19.3314 - val_loss: 1090.2677 - val_mean_absolute_error: 17.8972
# Epoch 131/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1145.9391 - mean_absolute_error: 18.2800 - val_loss: 1090.1121 - val_mean_absolute_error: 17.8910
# Epoch 132/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1021.2026 - mean_absolute_error: 17.8053 - val_loss: 1090.1360 - val_mean_absolute_error: 17.8668
# Epoch 133/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1011.1458 - mean_absolute_error: 17.8964 - val_loss: 1090.1881 - val_mean_absolute_error: 17.8419
# Epoch 134/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1191.4249 - mean_absolute_error: 18.1047 - val_loss: 1090.1940 - val_mean_absolute_error: 17.8320
# Epoch 135/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 950.4096 - mean_absolute_error: 17.8852 - val_loss: 1090.1810 - val_mean_absolute_error: 17.8025
# Epoch 136/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1026.9650 - mean_absolute_error: 17.9256 - val_loss: 1090.2219 - val_mean_absolute_error: 17.7841
# Epoch 137/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1581.6873 - mean_absolute_error: 20.2616 - val_loss: 1090.0015 - val_mean_absolute_error: 17.7890
# Epoch 138/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 956.1076 - mean_absolute_error: 17.6036 - val_loss: 1090.0957 - val_mean_absolute_error: 17.7617
# Epoch 139/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1237.9316 - mean_absolute_error: 19.2786 - val_loss: 1090.0104 - val_mean_absolute_error: 17.7568
# Epoch 140/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 944.2004 - mean_absolute_error: 17.4423 - val_loss: 1090.1462 - val_mean_absolute_error: 17.7338
# Epoch 141/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1230.7675 - mean_absolute_error: 17.8368 - val_loss: 1089.9062 - val_mean_absolute_error: 17.7466
# Epoch 142/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1049.0969 - mean_absolute_error: 18.7021 - val_loss: 1089.9299 - val_mean_absolute_error: 17.7383
# Epoch 143/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1285.9010 - mean_absolute_error: 18.1594 - val_loss: 1089.9137 - val_mean_absolute_error: 17.7263
# Epoch 144/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 902.7592 - mean_absolute_error: 16.9828 - val_loss: 1090.0751 - val_mean_absolute_error: 17.6943
# Epoch 145/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 853.1340 - mean_absolute_error: 17.1231 - val_loss: 1090.1200 - val_mean_absolute_error: 17.6698
# Epoch 146/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1029.6440 - mean_absolute_error: 17.5521 - val_loss: 1090.1316 - val_mean_absolute_error: 17.6662
# Epoch 147/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 858.4860 - mean_absolute_error: 16.5251 - val_loss: 1090.0948 - val_mean_absolute_error: 17.6539
# Epoch 148/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1111.1667 - mean_absolute_error: 18.4349 - val_loss: 1090.0560 - val_mean_absolute_error: 17.6573
# Epoch 149/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1433.3805 - mean_absolute_error: 19.0818 - val_loss: 1090.1344 - val_mean_absolute_error: 17.6432
# Epoch 150/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1208.7308 - mean_absolute_error: 18.2680 - val_loss: 1090.1387 - val_mean_absolute_error: 17.6303
# Epoch 151/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1039.7628 - mean_absolute_error: 17.7357 - val_loss: 1090.1006 - val_mean_absolute_error: 17.6156

# %%
model.evaluate(X_test, y_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 9165.9355 - mean_absolute_error: 23.6918
# [8831.6787109375, 24.361371994018555]
